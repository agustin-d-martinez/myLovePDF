# %% [markdown]
# pyside6-designer para abrir el designer

# %%
import os
import sys

# %%
# directorios

curr_dir = os.path.dirname(os.path.abspath(sys.argv[0]))
download_dir = os.path.join(curr_dir, "downloads")
download_dir.mkdir(exist_ok=True)

# %%
from libs.pdf import img_to_pdf

images = "D:\maste\Escritorio\Pruebas python"
outout_pdf = "D:\maste\Escritorio\Pruebas python\test\img_to_pdf.pdf"

img_to_pdf([images], outout_pdf)

# %%
from libs.pdf import add_blank_page

pdf_in = "D:\maste\Escritorio\Pruebas python\test\base.pdf"
pdf_out = "D:\maste\Escritorio\Pruebas python\test\with_blank.pdf"

add_blank_page(pdf_in, pdf_out, [2, 4])

# %%
from libs.media import extract_audio

video = "D:\maste\Escritorio\Pruebas python\test\video.mp4"
audio = "D:\maste\Escritorio\Pruebas python\test\audio.mp3"

extract_audio(video, audio)

# %%
from libs.media import get_video_info, summarize_formats, normalize_videos

url = "https://www.youtube.com/watch?v=XXXXXXXX"

info = get_video_info(url)
print(f"Título: {info.get("title")}\n\n\n")

info = normalize_videos(info)

for i in info:
    print("cancion:")
    print(summarize_formats(i))
    print("------------------------")

# %%
from libs.media import download_video

url = "https://www.youtube.com/watch?v=XXXXXXXX"
output_path = "D:\maste\Escritorio\Pruebas python\videos"

download_video(url=url, output_path=output_path, resolution=720)

# %%
from libs.media import download_audio

url = "https://www.youtube.com/watch?v=XXXXXXXX"
output_path = "D:\maste\Escritorio\Pruebas python\audio"

download_audio(url=url, output_path=output_path)
